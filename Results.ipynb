# %% [markdown]
# # Simple CNN: PGD Vs FGSM

# %%
import matplotlib.pyplot as plt

# Simple CNN - PGD
simple_cnn_accuracy = [97.19, 99.15, 99.44, 99.59, 99.67]
simple_cnn_loss = [175.4103, 53.0943, 34.6272, 24.3543, 20.9508]

# Simple CNN - FGSM
simple_cnn_loss_fgsm = [0.0958, 0.0289, 0.0186, 0.0133, 0.0120]
simple_cnn_accuracy_fgsm = [97.02, 99.11, 99.43, 99.58, 99.65]


epochs = range(1, len(simple_cnn_accuracy) + 1)

# Accuracy vs Epoch
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, simple_cnn_accuracy, label="Simple CNN - PGD", marker='o')
plt.plot(epochs, simple_cnn_accuracy_fgsm, label="Simple CNN - FGSM", marker='s')
plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)

# Loss vs Epoch
plt.subplot(1, 2, 2)
plt.plot(epochs, simple_cnn_loss, label="Simple CNN - PGD", marker='o')
plt.plot(epochs, simple_cnn_accuracy_fgsm, label="Simple CNN - FGSM", marker='s')
plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Deep CNN: PGD Vs FGSM

# %%
import matplotlib.pyplot as plt

# Data for SimpleCNN and DeepCNN (FGSM) based on the values you provided
deep_cnn_epochs = [1, 2, 3, 4, 5]
deep_cnn_loss_pgd = [33.5041, 25.8241, 29.0396, 23.9841,28.9961]
deep_cnn_accuracy_pgd = [99.69, 99.72, 99.70, 99.73, 99.68]

deep_cnn_loss_fgsm = [176.1927,54.9552, 36.6784, 27.3101,23.0498]
deep_cnn_accuracy_fgsm = [97.06, 99.12, 99.44, 99.58, 99.69]


# Plotting Accuracy vs Epoch
plt.figure(figsize=(12, 6))

# SimpleCNN Accuracy
plt.subplot(1, 2, 1)
plt.plot(deep_cnn_epochs, deep_cnn_accuracy_pgd, label='DeepCNN - PGD', color='blue', marker='o')
plt.plot(deep_cnn_epochs, deep_cnn_accuracy_fgsm, label='DeepCNN - FGSM', color='red', marker='x')
plt.title('Accuracy vs Epochs ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

# Plotting Loss vs Epoch
plt.subplot(1, 2, 2)
plt.plot(deep_cnn_epochs, deep_cnn_loss_pgd, label='DeepCNN - PGD', color='blue', marker='o')
plt.plot(deep_cnn_epochs, deep_cnn_loss_fgsm, label='DeepCNN - FGSM', color='red', marker='x')
plt.title('Loss vs Epochs ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Simple CNN Vs Deep CNN (PGD)

# %%
import matplotlib.pyplot as plt

# Data for SimpleCNN and DeepCNN (FGSM) based on the values you provided
deep_cnn_epochs = [1, 2, 3, 4, 5]
deep_cnn_loss = [33.5041, 25.8241, 29.0396, 23.9841,28.9961]
deep_cnn_accuracy = [99.69, 99.72, 99.70, 99.73, 99.72]

simple_cnn_loss = [175.4103,53.0943, 34.6272, 24.3543,20.9508]
simple_cnn_accuracy = [97.19, 99.15, 99.44, 99.59, 99.67]


# Plotting Accuracy vs Epoch
plt.figure(figsize=(12, 6))

# SimpleCNN Accuracy
plt.subplot(1, 2, 1)
plt.plot(deep_cnn_epochs, deep_cnn_accuracy, label='DeepCNN ', color='blue', marker='o')
plt.plot(deep_cnn_epochs, simple_cnn_accuracy, label='SimpleCNN', color='red', marker='x')
plt.title('Accuracy vs Epochs ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

# Plotting Loss vs Epoch
plt.subplot(1, 2, 2)
plt.plot(deep_cnn_epochs, deep_cnn_loss, label='DeepCNN ', color='blue', marker='o')
plt.plot(deep_cnn_epochs, simple_cnn_loss, label='SimpleCNN', color='red', marker='x')
plt.title('Loss vs Epochs ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Simple CNN Vs Deep CNN (FGSM)

# %%
import matplotlib.pyplot as plt

# Data for SimpleCNN and DeepCNN (FGSM) based on the values you provided
deep_cnn_epochs = [1, 2, 3, 4, 5]
simple_cnn_loss = [0.0958, 0.0289, 0.0186, 0.0133,0.0120]
simple_cnn_accuracy = [97.02, 99.11, 99.43, 99.58, 99.65]

deep_cnn_loss = [176.1927,54.9552, 36.6784, 27.3101,23.0498]
deep_cnn_accuracy = [97.06, 99.12, 99.44, 99.58, 99.69]


# Plotting Accuracy vs Epoch
plt.figure(figsize=(12, 6))

# SimpleCNN Accuracy
plt.subplot(1, 2, 1)
plt.plot(deep_cnn_epochs, deep_cnn_accuracy_pgd, label='DeepCNN - FGSM', color='blue', marker='o')
plt.plot(deep_cnn_epochs, deep_cnn_accuracy_fgsm, label='SimpleCNN - FGSM', color='red', marker='x')
plt.title('Accuracy vs Epochs(FGSM) ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

# Plotting Loss vs Epoch
plt.subplot(1, 2, 2)
plt.plot(deep_cnn_epochs, deep_cnn_loss_pgd, label='DeepCNN - FGSM', color='blue', marker='o')
plt.plot(deep_cnn_epochs, deep_cnn_loss_fgsm, label='SimpleCNN - FGSM', color='red', marker='x')
plt.title('Loss vs Epochs ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Display the plots
plt.tight_layout()
plt.show()
